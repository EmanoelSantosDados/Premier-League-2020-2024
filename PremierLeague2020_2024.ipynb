# %% [markdown]
# <a href="https://colab.research.google.com/github/EmanoelSantosDados/Premier-League-2020-2024/blob/main/PremierLeague2020_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise de dados e gráficos da Premier League**

# %%
# !pip install pandas matplotlib seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
df = pd.read_csv('/content/premier ligue.csv')

# %% [markdown]
# ## **Análise dos dados**

# %%
df.shape
# Out:
# (4788, 28)

# %%
df.sample(4)
# Out:
#       Unnamed: 0        date           time            comp         round  \
# 3330         159  2021-02-21  19:00 (21:00)  Premier League  Matchweek 25
# 2514         110  2021-10-03  16:30 (17:30)  Premier League   Matchweek 7
# 1053          39  2024-03-09  17:30 (19:30)  Premier League  Matchweek 28
# 1023          57  2024-05-11  12:30 (14:30)  Premier League  Matchweek 37
#
#       day venue result  gf  ga  ...  match report  notes  sh  sot  dist fk pk  \
# 3330  Sun  Home      W   3   1  ...  Match Report    NaN  14    6  19.1  0  1
# 2514  Sun  Away      D   2   2  ...  Match Report    NaN  12    3  17.0  1  0
# 1053  Sat  Home      W   2   1  ...  Match Report    NaN  17    5  16.4  0  0
# 1023  Sat  Away      W   4   0  ...  Match Report    NaN  15    8  17.6  0  1
#
#      pkatt season               team
# 3330     1   2021  Manchester United
# 2514     0   2022    Manchester City
# 1053     0   2024            Arsenal
# 1023     1   2024    Manchester City
#
# [4 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4788 entries, 0 to 4787
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    4788 non-null   int64
#  1   date          4788 non-null   object
#  2   time          4788 non-null   object
#  3   comp          4788 non-null   object
#  4   round         4788 non-null   object
#  5   day           4788 non-null   object
#  6   venue         4788 non-null   object
#  7   result        4788 non-null   object
#  8   gf            4788 non-null   int64
#  9   ga            4788 non-null   int64
#  10  opponent      4788 non-null   object
#  11  xg            4788 non-null   float64
#  12  xga           4788 non-null   float64
#  13  poss          4788 non-null   int64
#  14  attendance    3155 non-null   float64
#  15  captain       4788 non-null   object
#  16  formation     4788 non-null   object
#  17  referee       4788 non-null   object
#  18  match report  4788 non-null   object
#  19  notes         0 non-null      float64
#  20  sh            4788 non-null   int64
#  21  sot           4788 non-null   int64
#  22  dist          4786 non-null   float64
#  23  fk            4788 non-null   int64
#  24  pk            4788 non-null   int64
#  25  pkatt         4788 non-null   int64
#  26  season        4788 non-null   int64
#  27  team          4788 non-null   object
# dtypes: float64(5), int64(10), object(13)
# memory usage: 1.0+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'sh', 'sot', 'dist',
#        'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %% [markdown]
# ## **Excluindo colunas**
# Essas colunas não tem relevância para esse trabalho.

# %%
df.drop(columns=['Unnamed: 0', 'time', 'comp', 'xg', 'attendance', 'xga', 'captain', 'match report',
              'notes', 'sot', 'dist', 'fk', 'pk', 'pkatt'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#                 gf           ga         poss           sh       season
# count  4788.000000  4788.000000  4788.000000  4788.000000  4788.000000
# mean      1.447995     1.405388    50.432957    12.619256  2022.365079
# std       1.312635     1.286927    12.810958     5.548444     1.461850
# min       0.000000     0.000000    18.000000     0.000000  2020.000000
# 25%       0.000000     0.000000    41.000000     9.000000  2021.000000
# 50%       1.000000     1.000000    51.000000    12.000000  2023.000000
# 75%       2.000000     2.000000    60.000000    16.000000  2024.000000
# max       9.000000     9.000000    82.000000    36.000000  2024.000000

# %%
df.dtypes
# Out:
# date         object
# round        object
# day          object
# venue        object
# result       object
# gf            int64
# ga            int64
# opponent     object
# poss          int64
# formation    object
# referee      object
# sh            int64
# season        int64
# team         object
# dtype: object

# %% [markdown]
# ## **Tratando as colunas**

# %%
df["date"] = pd.to_datetime(df["date"], format='%Y-%m-%d', errors='coerce')  #Convertendo a data

#convertendo essas colunas em categoria para economizar memória e operações mais rápidas
df["venue"]=df["venue"].astype("category")
df["day"]=df["day"].astype("category")
df["result"]=df["result"].astype("category")
df["opponent"]=df["opponent"].astype("category")
df["team"]=df["team"].astype("category")
df["round"]=df["round"].astype("category")
df["referee"]=df["referee"].astype("category")
df["formation"]=df["formation"].astype("category")
df["season"]=df["season"].astype("category")

#convertendo dados em bits mais baixos
df["gf"]=df["gf"].astype(np.int8)
df["sh"]=df["sh"].astype(np.int8)

df.head()
# Out:
#         date        round  day venue result  gf  ga        opponent  poss  \
# 0 2020-09-21  Matchweek 2  Mon  Away      W   3   1          Wolves    65
# 1 2020-09-27  Matchweek 3  Sun  Home      L   2   5  Leicester City    72
# 2 2020-10-03  Matchweek 4  Sat  Away      D   1   1    Leeds United    49
# 3 2020-10-17  Matchweek 5  Sat  Home      W   1   0         Arsenal    58
# 4 2020-10-24  Matchweek 6  Sat  Away      D   1   1        West Ham    69
#
#   formation         referee  sh season             team
# 0   4-2-3-1  Andre Marriner  13   2024  Manchester City
# 1   4-2-3-1  Michael Oliver  16   2024  Manchester City
# 2     4-3-3       Mike Dean  23   2024  Manchester City
# 3   3-1-4-2  Chris Kavanagh  13   2024  Manchester City
# 4     4-3-3  Anthony Taylor  14   2024  Manchester City

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4788 entries, 0 to 4787
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       4788 non-null   datetime64[ns]
#  1   round      4788 non-null   category
#  2   day        4788 non-null   category
#  3   venue      4788 non-null   category
#  4   result     4788 non-null   category
#  5   gf         4788 non-null   int8
#  6   ga         4788 non-null   int64
#  7   opponent   4788 non-null   category
#  8   poss       4788 non-null   int64
#  9   formation  4788 non-null   category
#  10  referee    4788 non-null   category
#  11  sh         4788 non-null   int8
#  12  season     4788 non-null   category
#  13  team       4788 non-null   category
# dtypes: category(9), datetime64[ns](1), int64(2), int8(2)
# memory usage: 170.5 KB

# %%
premier = df.copy()

# %%
premier.columns
# Out:
# Index(['date', 'round', 'day', 'venue', 'result', 'gf', 'ga', 'opponent',
#        'poss', 'formation', 'referee', 'sh', 'season', 'team'],
#       dtype='object')

# %%
#Excluindo a palavra Matchweek
premier['round'] = premier['round'].str.replace('Matchweek', '')
premier
# Out:
#            date round  day venue result  gf  ga         opponent  poss  \
# 0    2020-09-21     2  Mon  Away      W   3   1           Wolves    65
# 1    2020-09-27     3  Sun  Home      L   2   5   Leicester City    72
# 2    2020-10-03     4  Sat  Away      D   1   1     Leeds United    49
# 3    2020-10-17     5  Sat  Home      W   1   0          Arsenal    58
# 4    2020-10-24     6  Sat  Away      D   1   1         West Ham    69
# ...         ...   ...  ...   ...    ...  ..  ..              ...   ...
# 4783 2020-07-07    34  Tue  Away      L   1   2          Watford    56
# 4784 2020-07-11    35  Sat  Home      L   0   4         West Ham    53
# 4785 2020-07-14    36  Tue  Away      L   0   1          Chelsea    33
# 4786 2020-07-18    37  Sat  Home      L   0   2          Burnley    42
# 4787 2020-07-26    38  Sun  Away      L   0   5  Manchester City    27
#
#      formation         referee  sh season             team
# 0      4-2-3-1  Andre Marriner  13   2024  Manchester City
# 1      4-2-3-1  Michael Oliver  16   2024  Manchester City
# 2        4-3-3       Mike Dean  23   2024  Manchester City
# 3      3-1-4-2  Chris Kavanagh  13   2024  Manchester City
# 4        4-3-3  Anthony Taylor  14   2024  Manchester City
# ...        ...             ...  ..    ...              ...
# 4783   4-2-3-1  Anthony Taylor  12   2020     Norwich City
# 4784   4-2-3-1    Kevin Friend  11   2020     Norwich City
# 4785   4-1-4-1   Jonathan Moss   2   2020     Norwich City
# 4786   4-2-3-1    Kevin Friend   6   2020     Norwich City
# 4787   4-2-3-1    Craig Pawson   5   2020     Norwich City
#
# [4788 rows x 14 columns]

# %% [markdown]
# ## **Traduzindo para português**

# %%
#Traduzindo colunas português
premier_col = {'date': 'data',
               'day': 'dia',
               'round': 'rodada',
               'venue': 'local',
               'referee': 'arbitro',
               'formation': 'formação_mand',
               'team': 'time',
               'opponent': 'visitante',
               'result': 'resultado',
               'gf': 'gols_mand',
               'ga': 'gols_visit',
               'sh': 'chutes_mand',
               'poss': 'posse_mand',
               'poss.1': 'posse_visit',
               'season': 'temporada',

}

#Traduzindo linhas português
premier_lin = {'Mon': 'Segunda',
               'Tue': 'Terça',
               'Wed': 'Quarta',
               'Thu': 'Quinta',
               'Fri': 'Sexta',
               'Sat': 'Sábado',
               'Sun': 'Domingo',
               'W': 'Vitória',
               'D': 'Empate',
               'L': 'Derrota',
               'Home': 'Mandante',
               'Away': 'Visitante',
}

# %%
premier.rename(columns=premier_col, inplace=True)
premier.replace(premier_lin, inplace=True)

premier.copy()
# Out:
#            data rodada      dia      local resultado  gols_mand  gols_visit  \
# 0    2020-09-21      2  Segunda  Visitante   Vitória          3           1
# 1    2020-09-27      3  Domingo   Mandante   Derrota          2           5
# 2    2020-10-03      4   Sábado  Visitante    Empate          1           1
# 3    2020-10-17      5   Sábado   Mandante   Vitória          1           0
# 4    2020-10-24      6   Sábado  Visitante    Empate          1           1
# ...         ...    ...      ...        ...       ...        ...         ...
# 4783 2020-07-07     34    Terça  Visitante   Derrota          1           2
# 4784 2020-07-11     35   Sábado   Mandante   Derrota          0           4
# 4785 2020-07-14     36    Terça  Visitante   Derrota          0           1
# 4786 2020-07-18     37   Sábado   Mandante   Derrota          0           2
# 4787 2020-07-26     38  Domingo  Visitante   Derrota          0           5
#
#             visitante  posse_mand formação_mand         arbitro  chutes_mand  \
# 0              Wolves          65       4-2-3-1  Andre Marriner           13
# 1      Leicester City          72       4-2-3-1  Michael Oliver           16
# 2        Leeds United          49         4-3-3       Mike Dean           23
# 3             Arsenal          58       3-1-4-2  Chris Kavanagh           13
# 4            West Ham          69         4-3-3  Anthony Taylor           14
# ...               ...         ...           ...             ...          ...
# 4783          Watford          56       4-2-3-1  Anthony Taylor           12
# 4784         West Ham          53       4-2-3-1    Kevin Friend           11
# 4785          Chelsea          33       4-1-4-1   Jonathan Moss            2
# 4786          Burnley          42       4-2-3-1    Kevin Friend            6
# 4787  Manchester City          27       4-2-3-1    Craig Pawson            5
#
#      temporada             time
# 0         2024  Manchester City
# 1         2024  Manchester City
# 2         2024  Manchester City
# 3         2024  Manchester City
# 4         2024  Manchester City
# ...        ...              ...
# 4783      2020     Norwich City
# 4784      2020     Norwich City
# 4785      2020     Norwich City
# 4786      2020     Norwich City
# 4787      2020     Norwich City
#
# [4788 rows x 14 columns]

# %% [markdown]
# ## **Criando colunas**

# %%
#Criando a coluna placar
premier['placar'] = premier['gols_mand'].astype(str) + '-' + premier['gols_visit'].astype(str)

#Criando a coluna posse_vist
premier['posse_visit'] = 100 - premier['posse_mand']

premier
# Out:
#            data rodada      dia      local resultado  gols_mand  gols_visit  \
# 0    2020-09-21      2  Segunda  Visitante   Vitória          3           1
# 1    2020-09-27      3  Domingo   Mandante   Derrota          2           5
# 2    2020-10-03      4   Sábado  Visitante    Empate          1           1
# 3    2020-10-17      5   Sábado   Mandante   Vitória          1           0
# 4    2020-10-24      6   Sábado  Visitante    Empate          1           1
# ...         ...    ...      ...        ...       ...        ...         ...
# 4783 2020-07-07     34    Terça  Visitante   Derrota          1           2
# 4784 2020-07-11     35   Sábado   Mandante   Derrota          0           4
# 4785 2020-07-14     36    Terça  Visitante   Derrota          0           1
# 4786 2020-07-18     37   Sábado   Mandante   Derrota          0           2
# 4787 2020-07-26     38  Domingo  Visitante   Derrota          0           5
#
#             visitante  posse_mand formação_mand         arbitro  chutes_mand  \
# 0              Wolves          65       4-2-3-1  Andre Marriner           13
# 1      Leicester City          72       4-2-3-1  Michael Oliver           16
# 2        Leeds United          49         4-3-3       Mike Dean           23
# 3             Arsenal          58       3-1-4-2  Chris Kavanagh           13
# 4            West Ham          69         4-3-3  Anthony Taylor           14
# ...               ...         ...           ...             ...          ...
# 4783          Watford          56       4-2-3-1  Anthony Taylor           12
# 4784         West Ham          53       4-2-3-1    Kevin Friend           11
# 4785          Chelsea          33       4-1-4-1   Jonathan Moss            2
# 4786          Burnley          42       4-2-3-1    Kevin Friend            6
# 4787  Manchester City          27       4-2-3-1    Craig Pawson            5
#
#      temporada             time placar  posse_visit
# 0         2024  Manchester City    3-1           35
# 1         2024  Manchester City    2-5           28
# 2         2024  Manchester City    1-1           51
# 3         2024  Manchester City    1-0           42
# 4         2024  Manchester City    1-1           31
# ...        ...              ...    ...          ...
# 4783      2020     Norwich City    1-2           44
# 4784      2020     Norwich City    0-4           47
# 4785      2020     Norwich City    0-1           67
# 4786      2020     Norwich City    0-2           58
# 4787      2020     Norwich City    0-5           73
#
# [4788 rows x 16 columns]

# %%
#Ordenando as colunas
premier = premier[['data', 'dia', 'rodada', 'local', 'arbitro', 'formação_mand', 'time',
                   'visitante', 'resultado', 'placar', 'gols_mand', 'gols_visit', 'posse_mand',
                   'posse_visit', 'chutes_mand', 'temporada']
]
premier.head()
# Out:
#         data      dia rodada      local         arbitro formação_mand  \
# 0 2020-09-21  Segunda      2  Visitante  Andre Marriner       4-2-3-1
# 1 2020-09-27  Domingo      3   Mandante  Michael Oliver       4-2-3-1
# 2 2020-10-03   Sábado      4  Visitante       Mike Dean         4-3-3
# 3 2020-10-17   Sábado      5   Mandante  Chris Kavanagh       3-1-4-2
# 4 2020-10-24   Sábado      6  Visitante  Anthony Taylor         4-3-3
#
#               time       visitante resultado placar  gols_mand  gols_visit  \
# 0  Manchester City          Wolves   Vitória    3-1          3           1
# 1  Manchester City  Leicester City   Derrota    2-5          2           5
# 2  Manchester City    Leeds United    Empate    1-1          1           1
# 3  Manchester City         Arsenal   Vitória    1-0          1           0
# 4  Manchester City        West Ham    Empate    1-1          1           1
#
#    posse_mand  posse_visit  chutes_mand temporada
# 0          65           35           13      2024
# 1          72           28           16      2024
# 2          49           51           23      2024
# 3          58           42           13      2024
# 4          69           31           14      2024

# %% [markdown]
# ## **Gráficos**

# %%
#Total de gols por rodada
total_gols = premier['gols_mand'] + premier['gols_visit']

plt.figure(figsize=(12, 6))
sns.barplot(x='rodada', y=total_gols, data=premier, palette='viridis')
plt.title('Goals Distribuição por rodada')
plt.xlabel('Rodada')
plt.ylabel('Gols')
plt.xticks(rotation=45)

plt.show()
# Out:
# <ipython-input-262-b5c3c1d8e669>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rodada', y=total_gols, data=premier, palette='viridis')

# %%
#Total de gols por temporada
plt.figure(figsize=(12, 6))
sns.barplot(x='temporada', y=total_gols, data=premier, palette='viridis')
plt.title('Goals Distribuição por temporada')
plt.xlabel('Temporada')
plt.ylabel('Gols')
plt.xticks(rotation=45)

plt.show()
# Out:
# <ipython-input-264-ca9aa846e790>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='temporada', y=total_gols, data=premier, palette='viridis')

# %%
#Resultados por temporadas
sns.countplot(data=premier, x="resultado",hue="temporada")
# Out:
# <Axes: xlabel='resultado', ylabel='count'>

# %%
#Resultados por dia
sns.countplot(data=premier, x="resultado", hue="dia")
# Out:
# <Axes: xlabel='resultado', ylabel='count'>

# %%
#Número de vitórias por dia
vitoria = premier.groupby("dia")["data"].count().reset_index(name='count')
sns.barplot(data=vitoria, x='dia', y='count', palette='viridis')
plt.xlabel('Dia da semana')
plt.ylabel('número de vitórias')
plt.title('Número de vitórias por dia da semana')

plt.show()
# Out:
# <ipython-input-267-36d3282b3221>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   vitoria = premier.groupby("dia")["data"].count().reset_index(name='count')
# <ipython-input-267-36d3282b3221>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=vitoria, x='dia', y='count', palette='viridis')

# %%
#Times com mais vitórias
vitoria = premier[premier["resultado"]=="Vitória"].groupby("time")["resultado"].count().sort_values(ascending=False)
vitoria.plot(kind="bar")
# Out:
# <ipython-input-268-02f80de1d086>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   vitoria = premier[premier["resultado"]=="Vitória"].groupby("time")["resultado"].count().sort_values(ascending=False)
# <Axes: xlabel='time'>

# %%
#Times com mais vitórias por temporada
premier2 = premier.copy()
premier2['Vitória'] = premier2['resultado'].apply(lambda x: 1 if x == 'Vitória' else 0)

temp_premier = premier2.pivot_table(index='time', columns='temporada', values='Vitória', aggfunc='sum')

plt.figure(figsize=(15, 15))
sns.heatmap(temp_premier, annot=True, linewidth=0.5, cmap='summer')
# Out:
# <Axes: xlabel='temporada', ylabel='time'>

# %%
temp_premier = premier2.pivot_table(index='time', columns='temporada', values='gols_mand', aggfunc='sum')

plt.figure(figsize=(15, 15))
sns.heatmap(temp_premier, annot=True, linewidth=0.5, cmap='summer',fmt="d")
# Out:
# <Axes: xlabel='temporada', ylabel='time'>

# %%
#Total partidas - juiz
arbitro = premier2.groupby("arbitro")["data"].count().sort_values(ascending=False)

arbitro.plot(kind="bar")
# Out:
# <ipython-input-272-10f8c984fc8c>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   arbitro = premier2.groupby("arbitro")["data"].count().sort_values(ascending=False)
# <Axes: xlabel='arbitro'>
